# %%
import numpy as np
import matplotlib.pyplot as plt

# Load datasets
dataset_no_presence = np.load('dataset/dataset-no-presence.npy')
dataset_presence = np.load('dataset/dataset-presence.npy')

print("Dataset (No Presence) shape:", dataset_no_presence.shape)
print("Dataset (Presence) shape:", dataset_presence.shape)
# Out:
# Dataset (No Presence) shape: (52, 8, 250)
# Dataset (Presence) shape: (52, 8, 250)

# %%
def compute_periodogram(csi_image):
    """
    Compute the 2D periodogram (power spectrum) of the input CSI image.
    - Apply 2D FFT
    - Shift frequencies to center
    - Remove DC components
    - Normalize to [0,1]
    """
    # Step 1: Apply 2D FFT
    fft_result = np.fft.fft2(csi_image)
    
    # Step 2: Shift zero frequency component to the center
    fft_shifted = np.fft.fftshift(fft_result)
    
    # Step 3: Compute the power spectrum (magnitude squared)
    periodogram = np.abs(fft_shifted) ** 2
    
    # Step 4: Remove DC components (center frequency at [mid_x, mid_y])
    mid_x, mid_y = periodogram.shape[0] // 2, periodogram.shape[1] // 2
    periodogram[mid_x, :] = 0  # Remove DC along x-axis
    periodogram[:, mid_y] = 0  # Remove DC along y-axis
    
    # Step 5: Normalize to [0,1]
    periodogram = (periodogram - periodogram.min()) / (periodogram.max() - periodogram.min())
    
    return periodogram

# %%
# Select a random capture index for visualization
capture_index = np.random.randint(0, 249)
print("Random capture index:", capture_index)

# Compute the magnitude response (absolute value of complex CSI)
magnitude_no_presence = np.abs(dataset_no_presence[:, :, capture_index])
magnitude_presence = np.abs(dataset_presence[:, :, capture_index])

# Create a horizontal subplot (1 row, 2 columns)
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Function to plot CSI magnitude spectrum
def plot_magnitude_spectrum(ax, data, title):
    X, Y = np.meshgrid(np.arange(data.shape[1]), np.arange(data.shape[0]))  # Create grid
    c = ax.pcolor(X, Y, data, cmap='jet', shading='auto')
    fig.colorbar(c, ax=ax, label="Magnitude Response")
    ax.set_xlabel("Packets")
    ax.set_ylabel("Subcarriers")
    ax.set_title(title)

# Plot both magnitude spectrums
plot_magnitude_spectrum(axes[0], magnitude_no_presence, f"CSI Magnitude Spectrum\n(No Presence) - Capture {capture_index+1}")
plot_magnitude_spectrum(axes[1], magnitude_presence, f"CSI Magnitude Spectrum\n(Presence) - Capture {capture_index+1}")

# Adjust layout and show
plt.tight_layout()
plt.show()
# Out:
# Random capture index: 63

# %%
# Select a random capture index for visualization
capture_index = np.random.randint(0, 250)  # Randomly choose a capture
print(f"Selected Capture Index: {capture_index}")

# Compute periodograms for presence and no-presence captures
periodogram_no_presence = compute_periodogram(dataset_no_presence[:, :, capture_index])
periodogram_presence = compute_periodogram(dataset_presence[:, :, capture_index])

# Create a horizontal subplot (1 row, 2 columns)
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Function to plot the periodogram using imshow()
def plot_periodogram(ax, data, title):
    c = ax.imshow(data, cmap='jet', aspect='auto', origin='lower', interpolation='sinc')
    fig.colorbar(c, ax=ax, label="Power Spectrum Intensity")  # Attach colorbar to correct axis
    ax.set_xlabel("Temporal Index (Packets)")
    ax.set_ylabel("Spatial Index (Subcarriers)")
    ax.set_title(title)

# Visualize periodograms
plot_periodogram(axes[0], periodogram_no_presence, f"CSI Periodogram - No Presence (Capture {capture_index})")
plot_periodogram(axes[1], periodogram_presence, f"CSI Periodogram - Presence (Capture {capture_index})")

plt.tight_layout()  # Adjust layout
plt.show()
# Out:
# Selected Capture Index: 75

# %%
# Randomly select 3 capture indices
np.random.seed(42)  # Set seed for reproducibility
random_captures = np.random.choice(250, 2, replace=False)  # Choose 3 unique indices
print(f"Selected Capture Indices: {random_captures}")

# Create a figure with 2 rows and 3 columns
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('Human Presence', fontsize=14, fontweight='bold')

# Plot Raw CSI and Periodogram for each capture
for i, capture_index in enumerate(random_captures):
    # Compute raw CSI magnitude
    raw_csi = np.abs(dataset_presence[:, :, capture_index])

    # Compute periodogram
    periodogram = compute_periodogram(raw_csi)

    # Plot Raw CSI magnitude (Top row)
    ax1 = axes[0, i]
    c1 = ax1.imshow(raw_csi, cmap='jet', aspect='auto', origin='lower', interpolation='none')
    fig.colorbar(c1, ax=ax1)
    ax1.set_title(f"Raw CSI (# {capture_index})")
    ax1.set_xlabel("Packets")
    ax1.set_ylabel("Subcarriers")

    # Plot Periodogram (Bottom row)
    ax2 = axes[1, i]
    # c2 = ax2.imshow(periodogram, cmap='jet', aspect='auto', origin='lower', interpolation='bicubic')
    c2=ax2.imshow(periodogram, cmap='jet', aspect='auto', origin='lower', interpolation='sinc')
    fig.colorbar(c2, ax=ax2)
    ax2.set_title(f"CSI Periodogram (# {capture_index})")
    ax2.set_xlabel("Temporal Index")
    ax2.set_ylabel("Spatial Index")

# Adjust layout and show the plot
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# Selected Capture Indices: [142   6]

# %%
# Randomly select 3 capture indices
np.random.seed(42)  # Set seed for reproducibility
random_captures = np.random.choice(250, 2, replace=False)  # Choose 3 unique indices
print(f"Selected Capture Indices: {random_captures}")

# Create a figure with 2 rows and 3 columns
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('No Presence', fontsize=14, fontweight='bold')

# Plot Raw CSI and Periodogram for each capture
for i, capture_index in enumerate(random_captures):
    # Compute raw CSI magnitude
    raw_csi = np.abs(dataset_no_presence[:, :, capture_index])

    # Compute periodogram
    periodogram = compute_periodogram(raw_csi)

    # Plot Raw CSI magnitude (Top row)
    ax1 = axes[0, i]
    c1 = ax1.imshow(raw_csi, cmap='jet', aspect='auto', origin='lower', interpolation='none')
    fig.colorbar(c1, ax=ax1)
    ax1.set_title(f"Raw CSI (# {capture_index})")
    ax1.set_xlabel("Packets")
    ax1.set_ylabel("Subcarriers")

    # Plot Periodogram (Bottom row)
    ax2 = axes[1, i]
    # c2 = ax2.imshow(periodogram, cmap='jet', aspect='auto', origin='lower', interpolation='bicubic')
    c2=ax2.imshow(periodogram, cmap='jet', aspect='auto', origin='lower', interpolation='sinc')
    fig.colorbar(c2, ax=ax2)
    ax2.set_title(f"CSI Periodogram (# {capture_index})")
    ax2.set_xlabel("Temporal Index")
    ax2.set_ylabel("Spatial Index")

# Adjust layout and show the plot
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# Selected Capture Indices: [142   6]

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# Define output directories for each label
output_dir_presence = "generated_images/Human_Presence"
output_dir_no_presence = "generated_images/No_Presence"

# Create directories if they don't exist
os.makedirs(output_dir_presence, exist_ok=True)
os.makedirs(output_dir_no_presence, exist_ok=True)

# Function to compute the periodogram using 2D-FFT
def compute_periodogram(csi_data):
    periodogram = np.abs(np.fft.fft2(csi_data))  # Compute 2D FFT magnitude
    periodogram = np.fft.fftshift(periodogram)  # Center the zero frequency component
    periodogram = (periodogram - np.min(periodogram)) / (np.max(periodogram) - np.min(periodogram))  # Normalize to [0,1]
    return periodogram

# Loop through all 250 captures and generate/save images
for capture_index in range(250):
    print(f"Processing Capture Index: {capture_index}")

    # Compute periodograms for presence and no-presence captures
    periodogram_no_presence = compute_periodogram(dataset_no_presence[:, :, capture_index])
    periodogram_presence = compute_periodogram(dataset_presence[:, :, capture_index])

    # Function to plot and save the periodogram
    def save_periodogram(data, title, save_path):
        fig, ax = plt.subplots(figsize=(6, 5))  # Create single plot
        c = ax.imshow(data, cmap='jet', aspect='auto', origin='lower', interpolation='sinc')
        fig.colorbar(c, ax=ax, label="Power Spectrum Intensity")
        ax.set_xlabel("Temporal Index (Packets)")
        ax.set_ylabel("Spatial Index (Subcarriers)")
        ax.set_title(title)
        
        plt.savefig(save_path, dpi=300, bbox_inches='tight')  # Save image
        plt.close(fig)  # Free memory

    # Save images separately in different folders
    save_path_no_presence = os.path.join(output_dir_no_presence, f"capture_{capture_index:03d}.png")
    save_path_presence = os.path.join(output_dir_presence, f"capture_{capture_index:03d}.png")

    save_periodogram(periodogram_no_presence, f"CSI Periodogram - No Presence (Capture {capture_index})", save_path_no_presence)
    save_periodogram(periodogram_presence, f"CSI Periodogram - Presence (Capture {capture_index})", save_path_presence)

print("All images saved successfully in respective folders!")
# Out:
# Processing Capture Index: 0
# Processing Capture Index: 1
# Processing Capture Index: 2
# Processing Capture Index: 3
# Processing Capture Index: 4
# Processing Capture Index: 5
# Processing Capture Index: 6
# Processing Capture Index: 7
# Processing Capture Index: 8
# Processing Capture Index: 9
# Processing Capture Index: 10
# Processing Capture Index: 11
# Processing Capture Index: 12
# Processing Capture Index: 13
# Processing Capture Index: 14
# Processing Capture Index: 15
# Processing Capture Index: 16
# Processing Capture Index: 17
# Processing Capture Index: 18
# Processing Capture Index: 19
# Processing Capture Index: 20
# Processing Capture Index: 21
# Processing Capture Index: 22
# Processing Capture Index: 23
# Processing Capture Index: 24
# Processing Capture Index: 25
# Processing Capture Index: 26
# Processing Capture Index: 27
# Processing Capture Index: 28
# Processing Capture Index: 29
# Processing Capture Index: 30
# Processing Capture Index: 31
# Processing Capture Index: 32
# Processing Capture Index: 33
# Processing Capture Index: 34
# Processing Capture Index: 35
# Processing Capture Index: 36
# Processing Capture Index: 37
# Processing Capture Index: 38
# Processing Capture Index: 39
# Processing Capture Index: 40
# Processing Capture Index: 41
# Processing Capture Index: 42
# Processing Capture Index: 43
# Processing Capture Index: 44
# Processing Capture Index: 45
# Processing Capture Index: 46
# Processing Capture Index: 47
# Processing Capture Index: 48
# Processing Capture Index: 49
# Processing Capture Index: 50
# Processing Capture Index: 51
# Processing Capture Index: 52
# Processing Capture Index: 53
# Processing Capture Index: 54
# Processing Capture Index: 55
# Processing Capture Index: 56
# Processing Capture Index: 57
# Processing Capture Index: 58
# Processing Capture Index: 59
# Processing Capture Index: 60
# Processing Capture Index: 61
# Processing Capture Index: 62
# Processing Capture Index: 63
# Processing Capture Index: 64
# Processing Capture Index: 65
# Processing Capture Index: 66
# Processing Capture Index: 67
# Processing Capture Index: 68
# Processing Capture Index: 69
# Processing Capture Index: 70
# Processing Capture Index: 71
# Processing Capture Index: 72
# Processing Capture Index: 73
# Processing Capture Index: 74
# Processing Capture Index: 75
# Processing Capture Index: 76
# Processing Capture Index: 77
# Processing Capture Index: 78
# Processing Capture Index: 79
# Processing Capture Index: 80
# Processing Capture Index: 81
# Processing Capture Index: 82
# Processing Capture Index: 83
# Processing Capture Index: 84
# Processing Capture Index: 85
# Processing Capture Index: 86
# Processing Capture Index: 87
# Processing Capture Index: 88
# Processing Capture Index: 89
# Processing Capture Index: 90
# Processing Capture Index: 91
# Processing Capture Index: 92
# Processing Capture Index: 93
# Processing Capture Index: 94
# Processing Capture Index: 95
# Processing Capture Index: 96
# Processing Capture Index: 97
# Processing Capture Index: 98
# Processing Capture Index: 99
# Processing Capture Index: 100
# Processing Capture Index: 101
# Processing Capture Index: 102
# Processing Capture Index: 103
# Processing Capture Index: 104
# Processing Capture Index: 105
# Processing Capture Index: 106
# Processing Capture Index: 107
# Processing Capture Index: 108
# Processing Capture Index: 109
# Processing Capture Index: 110
# Processing Capture Index: 111
# Processing Capture Index: 112
# Processing Capture Index: 113
# Processing Capture Index: 114
# Processing Capture Index: 115
# Processing Capture Index: 116
# Processing Capture Index: 117
# Processing Capture Index: 118
# Processing Capture Index: 119
# Processing Capture Index: 120
# Processing Capture Index: 121
# Processing Capture Index: 122
# Processing Capture Index: 123
# Processing Capture Index: 124
# Processing Capture Index: 125
# Processing Capture Index: 126
# Processing Capture Index: 127
# Processing Capture Index: 128
# Processing Capture Index: 129
# Processing Capture Index: 130
# Processing Capture Index: 131
# Processing Capture Index: 132
# Processing Capture Index: 133
# Processing Capture Index: 134
# Processing Capture Index: 135
# Processing Capture Index: 136
# Processing Capture Index: 137
# Processing Capture Index: 138
# Processing Capture Index: 139
# Processing Capture Index: 140
# Processing Capture Index: 141
# Processing Capture Index: 142
# Processing Capture Index: 143
# Processing Capture Index: 144
# Processing Capture Index: 145
# Processing Capture Index: 146
# Processing Capture Index: 147
# Processing Capture Index: 148
# Processing Capture Index: 149
# Processing Capture Index: 150
# Processing Capture Index: 151
# Processing Capture Index: 152
# Processing Capture Index: 153
# Processing Capture Index: 154
# Processing Capture Index: 155
# Processing Capture Index: 156
# Processing Capture Index: 157
# Processing Capture Index: 158
# Processing Capture Index: 159
# Processing Capture Index: 160
# Processing Capture Index: 161
# Processing Capture Index: 162
# Processing Capture Index: 163
# Processing Capture Index: 164
# Processing Capture Index: 165
# Processing Capture Index: 166
# Processing Capture Index: 167
# Processing Capture Index: 168
# Processing Capture Index: 169
# Processing Capture Index: 170
# Processing Capture Index: 171
# Processing Capture Index: 172
# Processing Capture Index: 173
# Processing Capture Index: 174
# Processing Capture Index: 175
# Processing Capture Index: 176
# Processing Capture Index: 177
# Processing Capture Index: 178
# Processing Capture Index: 179
# Processing Capture Index: 180
# Processing Capture Index: 181
# Processing Capture Index: 182
# Processing Capture Index: 183
# Processing Capture Index: 184
# Processing Capture Index: 185
# Processing Capture Index: 186
# Processing Capture Index: 187
# Processing Capture Index: 188
# Processing Capture Index: 189
# Processing Capture Index: 190
# Processing Capture Index: 191
# Processing Capture Index: 192
# Processing Capture Index: 193
# Processing Capture Index: 194
# Processing Capture Index: 195
# Processing Capture Index: 196
# Processing Capture Index: 197
# Processing Capture Index: 198
# Processing Capture Index: 199
# Processing Capture Index: 200
# Processing Capture Index: 201
# Processing Capture Index: 202
# Processing Capture Index: 203
# Processing Capture Index: 204
# Processing Capture Index: 205
# Processing Capture Index: 206
# Processing Capture Index: 207
# Processing Capture Index: 208
# Processing Capture Index: 209
# Processing Capture Index: 210
# Processing Capture Index: 211
# Processing Capture Index: 212
# Processing Capture Index: 213
# Processing Capture Index: 214
# Processing Capture Index: 215
# Processing Capture Index: 216
# Processing Capture Index: 217
# Processing Capture Index: 218
# Processing Capture Index: 219
# Processing Capture Index: 220
# Processing Capture Index: 221
# Processing Capture Index: 222
# Processing Capture Index: 223
# Processing Capture Index: 224
# Processing Capture Index: 225
# Processing Capture Index: 226
# Processing Capture Index: 227
# Processing Capture Index: 228
# Processing Capture Index: 229
# Processing Capture Index: 230
# Processing Capture Index: 231
# Processing Capture Index: 232
# Processing Capture Index: 233
# Processing Capture Index: 234
# Processing Capture Index: 235
# Processing Capture Index: 236
# Processing Capture Index: 237
# Processing Capture Index: 238
# Processing Capture Index: 239
# Processing Capture Index: 240
# Processing Capture Index: 241
# Processing Capture Index: 242
# Processing Capture Index: 243
# Processing Capture Index: 244
# Processing Capture Index: 245
# Processing Capture Index: 246
# Processing Capture Index: 247
# Processing Capture Index: 248
# Processing Capture Index: 249
# All images saved successfully in respective folders!
